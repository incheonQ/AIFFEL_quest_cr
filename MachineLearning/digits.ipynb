# %% [markdown]
# <a href="https://colab.research.google.com/github/incheonQ/AIFFEL_quest_cr/blob/main/MachineLearning/digits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
images = load_digits()['images']
target = load_digits()['target']
data = load_digits()['data']

# %%
# digiit 이미지 출력

import matplotlib.pyplot as plt

plt.imshow(images[0])
plt.show()

# %%
# t-sne로 차원 축소 후 이미지 출력
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2, random_state=0)
digits_tsne = tsne.fit_transform(data)

plt.scatter(digits_tsne[:, 0], digits_tsne[:, 1], c=target)
plt.colorbar()
plt.show()

# %%
# train_data_split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression

models = {
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'SVM': svm.SVC(),
    'SGD Classifier': SGDClassifier(),
    'Logistic Regression': LogisticRegression()
}

for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    print(f'{model_name} Report:')
    print(classification_report(y_test, y_pred))


# SVM이 가장 좋은 성능을 보인다.
# precision과 recall의 조화평균인 f-1 score가 높다.
# Out:
# Decision Tree Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.88      0.93        42
#            1       0.73      0.89      0.80        46
#            2       0.72      0.89      0.80        37
#            3       0.82      0.80      0.81        40
#            4       0.88      0.91      0.89        23
#            5       0.91      0.78      0.84        40
#            6       0.97      0.90      0.93        39
#            7       0.83      0.77      0.80        31
#            8       0.73      0.65      0.69        34
#            9       0.79      0.79      0.79        28
#
#     accuracy                           0.83       360
#    macro avg       0.83      0.83      0.83       360
# weighted avg       0.84      0.83      0.83       360
#
# Random Forest Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
# ...
